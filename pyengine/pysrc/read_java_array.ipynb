# %%
# %cd C:\Users\charl\Documents\GitHub\charlesnchr-dev\pyengine\pysrc
# Out:
# C:\Users\charl\Documents\GitHub\charlesnchr-dev\pyengine\pysrc

# %%
import numpy as np
import io
from PIL import Image
import pickle

data = pickle.load(open('data.pkl','rb'))

# %%
len(data)
# Out:
# 8390000

# %%
h = 2048
w = 2048
nch = 1
bytesPerPixel = 2 # MM parameter

npixels = h*w*bytesPerPixel

img = np.zeros((h,w,nch))

count = 0

for i in range(npixels):
    if nch > 1:
        ch = i % bytesPerPixel
    else:
        ch = 0
    pidx = i // bytesPerPixel
    row = pidx // w
    column = pidx % w
    if nch > 1:
        if ch == 0:    
            img[row,column,2] = data[i]
        elif ch == 1:
            img[row,column,1] = data[i]
        elif ch == 2:
            img[row,column,0] = data[i]
    else:
        img[row,column,0] = data[i]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-be28423cbf6b> in <module>
#      20
#      21     if ch == 0:
# ---> 22         img[row,column,2] = data[i]
#      23     elif ch == 1:
#      24         img[row,column,1] = data[i]
#
# IndexError: index 2 is out of bounds for axis 2 with size 1

# %%
import matplotlib.pyplot as plt

plt.imshow(img.astype('uint8'))
plt.show()

# %%
img = Image.frombuffer("RGBA",(w,h),data,"raw","BGRA").convert("RGB")

# %%
plt.imshow(img)

# %%
from skimage import io, exposure
import matplotlib.pyplot as plt
img = io.imread("C:/Users/charl/Desktop/Screenshot 2020-10-23 022051.png") / 255

# %%
import numpy as np
p1 = np.percentile(img,0)
p2 = np.percentile(img,70)
plt.imshow(img)
